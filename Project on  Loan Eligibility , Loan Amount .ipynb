# %% [markdown]
# # Problem Statement:
#     1. Loan Eligibilty
#     2. Loan Amount
#     3. Loan Amount Term

# %% [markdown]
# <h1 align="center" style="color:red">Loan Eligibility</h1>

# %%
import pandas as pd
train=pd.read_csv("/Users/User/Downloads/training_set.csv")
test=pd.read_csv("/Users/User/Downloads/testing_set.csv")
from warnings import filterwarnings
filterwarnings ("ignore")

# %%
train.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0         NaN             360.0
# 1              NaN             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %%
test.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001015   Male     Yes          0  Graduate            No
# 1  LP001022   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban

# %%
Y=train[["Loan_Status"]] # Loan_Status is a categorical column i.e it has Yes and No
X=train.drop(labels=["Loan_ID","Loan_Status"],axis=1) #while in X we can have either categorical or continous.

# %%
from PM8 import replacer,preprocessing
replacer(X)
X=preprocessing(X)#converting categorical columns into continous and standardization

# %%
X
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.072651          -0.554368    0.000000          0.279851
# 1           0.000000          -0.038610   -0.219273          0.279851
# 2          -0.394096          -0.554368   -0.957641          0.279851
# 3          -0.462412           0.252103   -0.314547          0.279851
# 4           0.097389          -0.554368   -0.064454          0.279851
# ..               ...                ...         ...               ...
# 609        -0.410479          -0.554368   -0.898095          0.279851
# 610        -0.212902          -0.554368   -1.267279         -2.518655
# 611         0.436842          -0.472284    1.269371          0.279851
# 612         0.356730          -0.554368    0.483367          0.279851
# 613        -0.134756          -0.554368   -0.159728          0.279851
#
#      Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# ...

# %%
replacer(train)

# %%
from PM8 import model_builder

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc= DecisionTreeClassifier(max_depth=1,random_state=31)

# %%
tp={"max_depth":range(1,20,1)}
from sklearn.model_selection import GridSearchCV
CV=GridSearchCV(dtc,tp,scoring="accuracy",cv=4)
GCV=CV.fit(X,Y)
GCV.best_params_
# Out:
# {'max_depth': 1}

# %%
model_builder(train,["Loan_Status"],["Loan_ID"],dtc)
# Out:
# training Accuracy:  0.7983706720977597
# testing Accuracy:  0.8536585365853658

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(random_state=31,max_depth=2)
abc = AdaBoostClassifier(dtc,random_state=21,n_estimators=1)

# %%
model_builder(train,["Loan_Status"],["Loan_ID"],abc)
# Out:
# training Accuracy:  0.8004073319755601
# testing Accuracy:  0.8536585365853658

# %%
from PM8 import CV_tune

# %%
tp={"n_estimators":range(1,40,1)}
from sklearn.model_selection import GridSearchCV
CV=GridSearchCV(abc,tp,scoring="accuracy",cv=4)
GCV=CV.fit(X,Y)
GCV.best_params_
# Out:
# {'n_estimators': 1}

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(random_state=21,n_estimators=35)

# %%
tp={"max_depth":range(1,20,1)}
from sklearn.model_selection import GridSearchCV
CV=GridSearchCV(rfc,tp,scoring="accuracy",cv=4)
GCV=CV.fit(X,Y)
GCV.best_params_
# Out:
# {'max_depth': 3}

# %%
rfc=RandomForestClassifier(random_state=21,n_estimators=35,max_depth=3)

# %%
model_builder(train,["Loan_Status"],["Loan_ID"],rfc)
# Out:
# training Accuracy:  0.8044806517311609
# testing Accuracy:  0.8455284552845529

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNC=KNeighborsClassifier(n_neighbors=19)

# %%
tp={"n_neighbors":range(1,40,1)}
from sklearn.model_selection import GridSearchCV
CV=GridSearchCV(KNC,tp,scoring="accuracy",cv=4)
GCV=CV.fit(X,Y)
GCV.best_params_
# Out:
# {'n_neighbors': 19}

# %%
model_builder(train,["Loan_Status"],["Loan_ID"],KNC)
# Out:
# training Accuracy:  0.7963340122199593
# testing Accuracy:  0.8455284552845529

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(random_state=31,max_depth=2)
abc = AdaBoostClassifier(dtc,random_state=21,n_estimators=1)
model=abc.fit(X,Y)

# %% [markdown]
# # Testing Data Set

# %%
test.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001015   Male     Yes          0  Graduate            No
# 1  LP001022   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban

# %%
X=test.drop(labels=["Loan_ID"],axis=1)

# %%
from PM8 import replacer,preprocessing

# %%
from PM8 import replacer,preprocessing
replacer(X)
X1=preprocessing(X)#converting categorical columns into continous and standardization

# %%
X1.isna().sum()
# Out:
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Gender_Female              0
# Gender_Male                0
# Married_No                 0
# Married_Yes                0
# Dependents_0               0
# Dependents_1               0
# Dependents_2               0
# Dependents_3+              0
# Education_Graduate         0
# Education_Not Graduate     0
# Self_Employed_No           0
# Self_Employed_Yes          0
# Property_Area_Rural        0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
pred= model.predict(X1)
pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...

# %%
test["predicted_Loan_Status"]=pred

# %%
test.drop(["Loan_ID"],axis=1)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %%
replacer(train)

# %%
train.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
C1=train[train.Loan_Status=="Y"] 
C2=test[test.predicted_Loan_Status=="Y"]

# %%
C1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
C2.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area',
#        'predicted_Loan_Status'],
#       dtype='object')

# %%
C2.columns=C1.columns
C2.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
D=pd.concat([C1,C2])

# %%
D.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# ...

# %%
D.index
# Out:
# Int64Index([  0,   2,   3,   4,   5,   6,   8,  10,  11,  12,
#             ...
#             357, 358, 359, 360, 361, 362, 363, 364, 365, 366],
#            dtype='int64', length=725)

# %%
D.shape
# Out:
# (725, 13)

# %%
D.index=range(0,725,1)
D.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0  146.412162             360.0
# 1           3000.0                0.0   66.000000             360.0
# 2           2583.0             2358.0  120.000000             360.0
# 3           6000.0                0.0  141.000000             360.0
# 4           5417.0             4196.0  267.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Urban           Y
# ...

# %%
D.isna().sum()
# Out:
# Loan_ID               0
# Gender                9
# Married               0
# Dependents           10
# Education             0
# Self_Employed        14
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            4
# Loan_Amount_Term      5
# Credit_History       28
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
replacer(D)

# %%
D.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
XD=D.drop(labels=["LoanAmount","Loan_ID"],axis=1)

# %%
YD=D[["LoanAmount"]]

# %%
XD1=preprocessing(XD)

# %%
XD1
# Out:
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0           0.115076          -0.812679          0.299641    1.789113e-01
# 1          -0.398192          -0.812679          0.299641    1.789113e-01
# 2          -0.473317           0.527410          0.299641    1.789113e-01
# 3           0.142280          -0.812679          0.299641    1.789113e-01
# 4           0.037248           1.571975          0.299641    1.789113e-01
# ..               ...                ...               ...             ...
# 720        -0.216413           0.197218          0.299641    1.789113e-01
# 721        -0.189570          -0.409743          0.299641    1.789113e-01
# 722        -0.353152           0.319975          0.299641    4.313415e-15
# 723        -0.037877           0.547301          0.299641    1.789113e-01
# 724         0.718783          -0.812679         -2.574782    1.789113e-01
#
#      Gender_Female  Gender_Male  Married_No  Married_Yes  Dependents_0  \
# ...

# %%
XD1.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term',
#        'Credit_History', 'Gender_Female', 'Gender_Male', 'Married_No',
#        'Married_Yes', 'Dependents_0', 'Dependents_1', 'Dependents_2',
#        'Dependents_3+', 'Education_Graduate', 'Education_Not Graduate',
#        'Self_Employed_No', 'Self_Employed_Yes', 'Property_Area_Rural',
#        'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status_Y'],
#       dtype='object')

# %%
XD1.shape
# Out:
# (725, 20)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr= DecisionTreeRegressor(max_depth=1,random_state=31)
model=dtr.fit(XD1,YD)

# %%
from sklearn.metrics import mean_absolute_error 
pred=model.predict(XD1)
mean_absolute_error(YD,pred)
# Out:
# 42.59703779869238

# %%
from sklearn.metrics import mean_squared_error 
pred=model.predict(XD1)
mean_squared_error (YD,pred)
# Out:
# 4242.725170585145

# %%
XD2=test[test.predicted_Loan_Status=="N"]
replacer(XD2)

# %%
XD2.isna().sum()
# Out:
# Loan_ID                  0
# Gender                   0
# Married                  0
# Dependents               0
# Education                0
# Self_Employed            0
# ApplicantIncome          0
# CoapplicantIncome        0
# LoanAmount               0
# Loan_Amount_Term         0
# Credit_History           0
# Property_Area            0
# predicted_Loan_Status    0
# dtype: int64

# %%
XD2=XD2.drop(labels=["LoanAmount","Loan_ID"],axis=1)

# %%
XD3=train.drop(labels=["LoanAmount","Loan_ID"],axis=1)

# %%
XD3.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
XD2.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term',
#        'Credit_History', 'Property_Area', 'predicted_Loan_Status'],
#       dtype='object')

# %%
XD3.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term',
#        'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
XD2.columns=XD3.columns

# %%
XD2.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term',
#        'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
XD2.index
# Out:
# Int64Index([  7,  13,  25,  35,  55,  58,  63,  66,  67,  69,  80,  82,  84,
#              85,  94, 101, 106, 117, 118, 119, 123, 124, 126, 140, 142, 147,
#             153, 161, 165, 166, 168, 173, 174, 192, 193, 196, 198, 211, 224,
#             229, 230, 235, 236, 237, 241, 243, 245, 250, 255, 266, 268, 273,
#             274, 278, 284, 293, 301, 311, 317, 325, 339, 346, 351, 354],
#            dtype='int64')

# %%
XD2.shape
# Out:
# (64, 11)

# %%
XD2.index=range(0,64,1)

# %%
XD2.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          2  Not Graduate            No             3881
# 1   Male     Yes          2      Graduate            No            12173
# 2   Male      No          0      Graduate            No                0
# 3   Male      No          0      Graduate            No             3150
# 4   Male      No          0      Graduate            No             2750
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History Property_Area  \
# 0                  0             360.0             0.0         Rural
# 1                  0             360.0             0.0     Semiurban
# 2              24000             360.0             0.0         Rural
# 3                  0             360.0             0.0     Semiurban
# 4                  0             360.0             0.0         Urban
#
#   Loan_Status
# 0           N
# 1           N
# 2           N
# 3           N
# 4           N

# %%
XD5=preprocessing(XD2)

# %%
XD5.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term',
#        'Credit_History', 'Gender_Female', 'Gender_Male', 'Married_No',
#        'Married_Yes', 'Dependents_0', 'Dependents_1', 'Dependents_2',
#        'Dependents_3+', 'Education_Graduate', 'Education_Not Graduate',
#        'Self_Employed_No', 'Self_Employed_Yes', 'Property_Area_Rural',
#        'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status_N'],
#       dtype='object')

# %%
XD1.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term',
#        'Credit_History', 'Gender_Female', 'Gender_Male', 'Married_No',
#        'Married_Yes', 'Dependents_0', 'Dependents_1', 'Dependents_2',
#        'Dependents_3+', 'Education_Graduate', 'Education_Not Graduate',
#        'Self_Employed_No', 'Self_Employed_Yes', 'Property_Area_Rural',
#        'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status_Y'],
#       dtype='object')

# %%
XD5.columns=XD1.columns

# %%
model.predict(XD5)
# Out:
# array([125.36756284, 239.55507309, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 239.55507309, 239.55507309, 125.36756284,
#        239.55507309, 239.55507309, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 239.55507309, 125.36756284, 125.36756284,
#        239.55507309, 125.36756284, 125.36756284, 239.55507309,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 239.55507309, 239.55507309,
#        125.36756284, 125.36756284, 239.55507309, 125.36756284,
#        239.55507309, 125.36756284, 125.36756284, 125.36756284,
# ...

# %%
pred=model.predict(XD5)
pred
# Out:
# array([125.36756284, 239.55507309, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 239.55507309, 239.55507309, 125.36756284,
#        239.55507309, 239.55507309, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 239.55507309, 125.36756284, 125.36756284,
#        239.55507309, 125.36756284, 125.36756284, 239.55507309,
#        125.36756284, 125.36756284, 125.36756284, 125.36756284,
#        125.36756284, 125.36756284, 239.55507309, 239.55507309,
#        125.36756284, 125.36756284, 239.55507309, 125.36756284,
#        239.55507309, 125.36756284, 125.36756284, 125.36756284,
# ...
